# %% [markdown]
# <a href="https://colab.research.google.com/github/Walaga/Pothole-detector/blob/master/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title [IMPORTANT] Run Cell to Set up Environment {display-mode: "form"}
# %%capture
# 1. Create a directory named `object_detection`, this is where the model files will be stored.
# 2. Download and install the Tensorflow Object Detection API models using [Git](https://en.wikipedia.org/wiki/Git) into the `object_detection` folder.
# 3. Install the required libraries for the API.
# 4. Install TF-Slim, a lightweight library for defining, training and evaluating complex models in TensorFlow.

# We shall import the os library, it provides a number of functions that allow 
# interaction with the operating environment.
import os
import json
import sys
import glob
import urllib
import io
import xml.etree.ElementTree as ET
import argparse
from pathlib import Path
import numpy as np
from shutil import copyfile
import csv
import pandas as pd
from PIL import Image
from tqdm import tqdm
import tensorflow.compat.v1 as tf
from collections import namedtuple

# 1. Create a directory named detection
# !mkdir detection
os.chdir('detection')

# 2a. Download and install the Tensorflow Object Detection API models using Git into the object_detection folder,
# we use git command to get the source files from GitHub, git is preinstalled in the Google Colab environment.
# !git clone --depth 1 https://github.com/tensorflow/models.git

# 2b. Add the folder to the path, this allows to import 
#     scripts as we do with install libraries
os.environ['PYTHONPATH'] += ':'+'/content/detection/models'

# 3. Install the required libraries for the API. The libraries are installed
#    from the setup.py.

# 3a. First we shall move into research/models, this is where the setup.py script
#     is stored.
# %cd models/research

# Import dataset preparations from the object detection folder
from object_detection.utils import dataset_util

# 3b. This commands the environment to run the setup.py script if it exists.
# !pip install .

# 4. Install TF-Slim, a lightweight library for defining, training and evaluating complex models in TensorFlow.
# !pip install tf_slim

# 5a. Install the protobuf dependencies.
# !protoc object_detection/protos/*.proto --python_out=.;
pwd = os.getcwd();

# 5b. Add TF_slim to the system path.
os.environ['PYTHONPATH'] += f':{pwd}:{pwd}/slim';

# 6. Move back to the object_detection folder.
# %cd ../../

def split_indices(x, train=0.8, test=0.0, validate=0.2, shuffle=True):
    """
      Returns the indices at which the data is split.
    """
    # split training data
    n = len(x)
    v = np.arange(n)
    if shuffle:
        np.random.shuffle(v)

    i = round(n * train)  # train
    j = round(n * test) + i  # test
    k = round(n * validate) + j  # validate
    return v[:i], v[i:j], v[j:k]  # return indices

def split_files(file_names,train=0.8, test=0.2, validate=0.0):
    """
      Split the files provided according to the specified distributions.

      file_names  this is a list of file names that are split.
      train       the distribution for the train files, 0 <= x <= 1
      test        the distribution for the test files, it should complement train to add to one.
                  i.e. if train is 0.8, test should be 0.2 such that 0.8 + 0.2 = 1.0
      validate    this is the distribution for the validation set, it should also 
                  complement the train and test values i.e if train is 0.8, test is 0.1, validate
                  should be 0.1 such that 0.8 + 0.1 + 0.1 = 1.0

      Returns:
        (tuple) train, test, val
                train   a list containing the file names of the train set
                test    a list containing the file names of the test set
                val     a list containing the file name of the validation set
    """
    # split training data
    file_name = list(filter(lambda x: len(x) > 0, file_names))
    file_name = sorted(file_name)
    i, j, k = split_indices(file_names, train=train, test=test, validate=validate)
    train = []
    test = []
    val = []
    datasets = {'train': i, 'test': j, 'val': k}
    for key, item in datasets.items():
        if item.any():
            for ix in item:
                if key == 'train':
                    train.append(file_names[ix])
                if key == 'test':
                    test.append(file_names[ix])
                if key == 'val':
                    val.append(file_names[ix])

    return train, test, val

def json_to_csv(file_names, images_dir, labels_path, annotations_dir, label_file_name):
  """
  Converts a JSON file to a csv file.

  file_names       list of file names.
  images_dir       path to the images directory
  labels_path      is the path to the labels JSON file.
  annotations_dir  is the directory in which the annotations will be stored.
  label_file_name  is the name of the output .csv file i.e. labels_train.csv
  """
  # Load coco file
  f = open(labels_path, 'r')
  COCO_DATA = json.load(f)
  f.close()

  images = COCO_DATA["images"]
  annotations = COCO_DATA["annotations"]
      
  # Generating the csv in the annotations folder under data directory. (Ideally)
  csv_file_name = os.path.join(str(annotations_dir), label_file_name)

  class_name = 'pothole' # Normally, there will be more than one class, extract accordingly.

  with open(csv_file_name, 'w') as csv_label_file:
    f = csv.writer(csv_label_file)
    f.writerow(['file_name', 'width', 'height', 'class', 'xmin', 'ymin', 
                'xmax', 'ymax'])

    for file_name in tqdm(file_names, desc = "Processing CSV"):
        id = None
        for image in images:
          if file_name == image['file_name']:
            id = image['id']

        im = Image.open(os.path.join(images_dir, file_name))
        width, height = im.size

        for annotation in annotations:
            if id == annotation['image_id']:
                bbox = annotation['bbox']

                # COCO bbox label format: [xmin, ymin, width, height]
                xmin = bbox[0]
                xmax = bbox[0] + bbox[2]
                ymin = bbox[1]
                ymax = bbox[1] + bbox[3]

                # Write to .csv file.
                f.writerow([file_name, width, height, class_name, xmin, ymin, xmax, ymax])  

def create_pbtxt(annotations_dir):
  """
    Creates a pbtxt file.

    TensorFlow requires a label map, which maps each of the used labels 
    to an integer values. This label map is used both by the training and detection 
    processes. Notice the labels are one-indexed i.e. start at 1 (one).

    Example:
    # example.pbtxt
    item {
      id: 1
      name: 'cat'
    }

    item {
      id: 2
      name: 'dog'
    }

    The file is stored under the annotations folder.
  """
  # Create the label map
  label_map_path = os.path.join(annotations_dir, "label_map.pbtxt")
  pbtxt_content = ""

  class_name = 'pothole' # Could be more than one class name.

  pbtxt_content = (
      pbtxt_content
      + "item {{\n    id: {0}\n    name: '{1}'\n}}\n\n".format(1, class_name)
  )
  pbtxt_content = pbtxt_content.strip()
  with open(label_map_path, "w") as f:
      f.write(pbtxt_content)

def move_files(files, source, dest):
  """Move files from the source directory to the destination directory."""
  for filename in files:
    copyfile(os.path.join(source, filename),
                 os.path.join(dest, filename))
    
def class_text_to_int(row_label):
  if row_label == 'pothole': # the respective class_name
    return 1
  else:
    None

def split(df, group):
    data = namedtuple('data', ['filename', 'object'])
    gb = df.groupby(group)
    return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]

def create_tf_example(group, path):
    with tf.io.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    width, height = image.size

    filename = group.filename.encode('utf8')
    image_format = b'jpg'
    # check if the image format is matching with your images.
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []

    for index, row in group.object.iterrows():
        xmins.append(row['xmin'] / width)
        xmaxs.append(row['xmax'] / width)
        ymins.append(row['ymin'] / height)
        ymaxs.append(row['ymax'] / height)
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))

    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

def create_tfrecord(labels_file, images_dir, annotations_dir):
  """
    Create a tfrecord from the .csv file.
  """
  csv_name = labels_file.split('/')[-1][:-4]
  writer = tf.io.TFRecordWriter(os.path.join(annotations_dir, csv_name + '.record'))
  path = os.path.join(images_dir)
  examples = pd.read_csv(labels_file)
  grouped = split(examples, 'file_name')
  for group in grouped:
    tf_example = create_tf_example(group, path)
    writer.write(tf_example.SerializeToString())
  writer.close()
  print('Successfully created the TFRecords: {}'.format(csv_name + '.record'))

# The training helper function.
def train_model(path):
  """
    This is a helper function to aid with the training.
  """
  # !python workspace/data/model_main_tf2.py \
    --model_dir=workspace/data/training \
    --pipeline_config_path={path}

# The model exporter helper function.
def export_model(config_path, checkpoint_dir, export_dir):
  """
    This function calls the model exporter script that creates the graph format
    of the model that can be exported.
  """
  # !python workspace/data/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path {config_path} \
    --trained_checkpoint_dir {checkpoint_dir} \
    --output_directory {export_dir}


# Finally, we prepare the workspace folders as discussed in the last notebook. 
# Refer to it for details.
# Let's go ahead and create the folders.
# !mkdir workspace
# !mkdir workspace/data
# !mkdir workspace/data/annotations
# !mkdir workspace/data/images
# !mkdir workspace/data/images/train
# !mkdir workspace/data/images/test 
# !mkdir workspace/data/pre-trained-model
# !mkdir workspace/data/training

# Copy the model_main.py into the object_detection/workspace/data
# This is to aid with the training later on.
copyfile('/content/detection/models/research/object_detection/model_main_tf2.py',\
         '/content/detection/workspace/data/model_main_tf2.py')

copyfile('/content/detection/models/research/object_detection/exporter_main_v2.py', \
         '/content/detection/workspace/data/exporter_main_v2.py')

# %%
# %cd ..
# Out:
# /content

# %%
! git clone https://github.com/Walaga/detector.git
# Out:
# fatal: destination path 'detector' already exists and is not an empty directory.

# %%
# %cd ./annotations/
# Out:
# /content/detection/workspace/data/annotations

# %%
# !unzip /content/detector/files.zip
# Out:
# Archive:  /content/detector/files.zip
#   inflating: test.csv
#   inflating: train.csv

# %%
annotations_dir = r'/content/detection/workspace/data/annotations'
create_pbtxt(annotations_dir)

# %%
# %cd ..
# Out:
# /content/detection/workspace/data

# %%
# 1. Download the pretrained weights of your choice from TensorFlow’s detection model zoo.
PRE_TRAINED_MODEL_DIR = r'/content/detection/workspace/data/pre-trained-model'
MODEL = 'ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz'

# !wget -P {PRE_TRAINED_MODEL_DIR} http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !tar -zxvf {PRE_TRAINED_MODEL_DIR}/{MODEL} -C {PRE_TRAINED_MODEL_DIR} # Extract to a given directory
# Out:
# --2020-10-22 18:40:07--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.12.240, 2607:f8b0:4004:807::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.12.240|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘/content/detection/workspace/data/pre-trained-model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233.48M   237MB/s    in 1.0s
#
# 2020-10-22 18:40:08 (237 MB/s) - ‘/content/detection/workspace/data/pre-trained-model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]
#
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
# %cd ./annotations/
# Out:
# /content/detection/workspace/data/annotations

# %%
# !unzip /content/detector/tfrecords.zip
# Out:
# Archive:  /content/detector/tfrecords.zip
#   inflating: train.record
#   inflating: test.record

# %%
# %cd ..
# Out:
# /content/detection/workspace/data

# %%
# %cd ./images
# Out:
# /content/detection/workspace/data/images

# %%
# %cd ./test/
# Out:
# /content/detection/workspace/data/images/test

# %%
# !unzip /content/detector/test.zip
# Out:
# Archive:  /content/detector/test.zip
#   inflating: pothole 2 (1).jpg
#   inflating: pothole 2 (2).jpg
#   inflating: pothole 2 (3).jpg
#   inflating: pothole 2 (4).jpg
#   inflating: pothole 2 (5).jpg
#   inflating: pothole 2 (6).jpg
#   inflating: pothole 2 (7).jpg
#   inflating: pothole 2 (8).jpg
#   inflating: pothole 2 (9).jpg
#   inflating: pothole 2 (10).jpg
#   inflating: pothole 2 (11).jpg
#   inflating: pothole 2 (12).jpg
#   inflating: pothole 2 (13).jpg
#   inflating: pothole 2 (14).jpg
#   inflating: pothole 2 (15).jpg
#   inflating: pothole 2 (16).jpg
#   inflating: pothole 2 (17).jpg
#   inflating: pothole 2 (18).jpg
#   inflating: pothole 2 (19).jpg
#   inflating: pothole 2 (20).jpg
#   inflating: pothole 2 (21).jpg
#   inflating: pothole 2 (22).jpg
#   inflating: pothole 2 (23).jpg
#   inflating: pothole 2 (24).jpg
#   inflating: pothole 2 (25).jpg
#   inflating: pothole 2 (26).jpg
#   inflating: pothole 2 (27).jpg
#   inflating: pothole 2 (28).jpg
#   inflating: pothole 2 (29).jpg
#   inflating: pothole 2 (30).jpg
#   inflating: pothole 2 (31).jpg
#   inflating: pothole 2 (32).jpg
#   inflating: pothole 2 (33).jpg
#   inflating: pothole 2 (34).jpg
#   inflating: pothole 2 (35).jpg
#   inflating: pothole 2 (36).jpg
#   inflating: pothole 2 (37).jpg
#   inflating: pothole 2 (38).jpg
#   inflating: pothole 2 (39).jpg
#   inflating: pothole 2 (40).jpg
#   inflating: pothole 2 (41).jpg
#   inflating: pothole 2 (42).jpg
#   inflating: pothole 2 (43).jpg
#   inflating: pothole 2 (44).jpg
#   inflating: pothole 2 (45).jpg
#   inflating: pothole 2 (46).jpg
#   inflating: pothole 2 (47).jpg
#   inflating: pothole 2 (48).jpg
#   inflating: pothole 2 (49).jpg
#   inflating: pothole 2 (50).jpg
#   inflating: pothole 2 (51).jpg
#   inflating: pothole 2 (52).jpg
#   inflating: pothole 2 (53).jpg
#   inflating: pothole 2 (54).jpg
#   inflating: pothole 2 (55).jpg
#   inflating: pothole 2 (56).jpg
#   inflating: pothole 2 (57).jpg
#   inflating: pothole 2 (58).jpg
#   inflating: pothole 2 (59).jpg
#   inflating: pothole 2 (60).jpg
#   inflating: pothole 2 (61).jpg
#   inflating: pothole 2 (62).jpg
#   inflating: pothole 2 (63).jpg
#   inflating: pothole 2 (64).jpg
#   inflating: pothole 2 (65).jpg
#   inflating: pothole 2 (66).jpg
#   inflating: pothole 2 (67).jpg
#   inflating: pothole 2 (68).jpg
#   inflating: pothole 2 (69).jpg
#   inflating: pothole 2 (70).jpg
#   inflating: pothole 2 (71).jpg
#   inflating: pothole 2 (72).jpg
#   inflating: pothole 2 (73).jpg
#   inflating: pothole 2 (74).jpg
#   inflating: pothole 2 (75).jpg
#   inflating: pothole 2 (76).jpg
#   inflating: pothole 2 (77).jpg
#   inflating: pothole 2 (78).jpg
#   inflating: pothole 2 (79).jpg
#   inflating: pothole 2 (80).jpg
#   inflating: pothole 2 (81).jpg
#   inflating: pothole 2 (82).jpg
#   inflating: pothole 2 (83).jpg
#   inflating: pothole 2 (84).jpg
#   inflating: pothole 2 (85).jpg
#   inflating: pothole 2 (86).jpg
#   inflating: pothole 2 (87).jpg
#   inflating: pothole 2 (88).jpg
#   inflating: pothole 2 (89).jpg
#   inflating: pothole 2 (90).jpg
#   inflating: pothole 2 (91).jpg
#   inflating: pothole 2 (92).jpg
#   inflating: pothole 2 (93).jpg
#   inflating: pothole 2 (94).jpg
#   inflating: pothole 2 (95).jpg
#   inflating: pothole 2 (96).jpg
#   inflating: pothole 2 (97).jpg
#   inflating: pothole 2 (98).jpg
#   inflating: pothole 2 (99).jpg
#   inflating: pothole 2 (100).jpg
#   inflating: pothole 2 (101).jpg
#   inflating: pothole 2 (102).jpg
#   inflating: pothole 2 (103).jpg
#   inflating: pothole 2 (104).jpg
#   inflating: pothole 2 (105).jpg
#   inflating: pothole 2 (106).jpg
#   inflating: pothole 2 (107).jpg
#   inflating: pothole 2 (108).jpg
#   inflating: pothole 2 (109).jpg
#   inflating: pothole 2 (110).jpg
#   inflating: pothole 2 (111).jpg
#   inflating: pothole 2 (112).jpg
#   inflating: pothole 2 (113).jpg
#   inflating: pothole 2 (114).jpg
#   inflating: pothole 2 (115).jpg
#   inflating: pothole 2 (116).jpg
#   inflating: pothole 2 (117).jpg
#   inflating: pothole 2 (118).jpg
#   inflating: pothole 2 (119).jpg
#   inflating: pothole 2 (120).jpg
#   inflating: pothole 2 (121).jpg
#   inflating: pothole 2 (122).jpg
#   inflating: pothole 2 (123).jpg
#   inflating: pothole 2 (124).jpg
#   inflating: pothole 2 (125).jpg
#   inflating: pothole 2 (126).jpg
#   inflating: pothole 2 (127).jpg
#   inflating: pothole 2 (128).jpg
#   inflating: pothole 2 (129).jpg
#   inflating: pothole 2 (130).jpg
#   inflating: pothole 2 (131).jpg
#   inflating: pothole 2 (132).jpg
#   inflating: pothole 2 (133).jpg
#   inflating: pothole 2 (134).jpg
#   inflating: pothole 2 (135).jpg
#   inflating: pothole 2 (136).jpg
#   inflating: pothole 2 (137).jpg
#   inflating: pothole 2 (138).jpg
#   inflating: pothole 2 (139).jpg
#   inflating: pothole 2 (140).jpg
#   inflating: pothole 2 (141).jpg
#   inflating: pothole 2 (142).jpg
#   inflating: pothole 2 (143).jpg
#   inflating: pothole 2 (144).jpg
#   inflating: pothole 2 (145).jpg
#   inflating: pothole 2 (146).jpg
#   inflating: pothole 2 (147).jpg
#   inflating: pothole 2 (148).jpg
#   inflating: pothole 2 (149).jpg
#   inflating: pothole 2 (150).jpg
#   inflating: pothole 2 (151).jpg
#   inflating: pothole 2 (152).jpg
#   inflating: pothole 2 (153).jpg
#   inflating: pothole 2 (154).jpg
#   inflating: pothole 2 (155).jpg
#   inflating: pothole 2 (156).jpg
#   inflating: pothole 2 (157).jpg
#   inflating: pothole 2 (158).jpg
#   inflating: pothole 2 (159).jpg
#   inflating: pothole 2 (160).jpg
#   inflating: pothole 2 (161).jpg
#   inflating: pothole 2 (162).jpg
#   inflating: pothole 2 (163).jpg
#   inflating: pothole 2 (164).jpg
#   inflating: pothole 2 (165).jpg
#   inflating: pothole 2 (166).jpg
#   inflating: pothole 2 (167).jpg
#   inflating: pothole 2 (168).jpg
#   inflating: pothole 2 (169).jpg
#   inflating: pothole 2 (170).jpg
#   inflating: pothole 2 (171).jpg
#   inflating: pothole 2 (172).jpg
#   inflating: pothole 2 (173).jpg
#   inflating: pothole 2 (174).jpg
#   inflating: pothole 2 (175).jpg
#   inflating: pothole 2 (176).jpg
#   inflating: pothole 2 (177).jpg
#   inflating: pothole 2 (178).jpg
#   inflating: pothole 2 (179).jpg
#   inflating: pothole 2 (180).jpg
#   inflating: pothole 2 (181).jpg
#   inflating: pothole 2 (182).jpg
#   inflating: pothole 2 (183).jpg
#   inflating: pothole 2 (184).jpg
#   inflating: pothole 2 (185).jpg
#   inflating: pothole 2 (186).jpg
#   inflating: pothole 2 (187).jpg
#   inflating: pothole 2 (188).jpg
#   inflating: pothole 2 (189).jpg
#   inflating: pothole 2 (190).jpg
#   inflating: pothole 2 (191).jpg
#   inflating: pothole 2 (192).jpg
#   inflating: pothole 2 (193).jpg
#   inflating: pothole 2 (194).jpg
#   inflating: pothole 2 (195).jpg
#   inflating: pothole 2 (196).jpg
#   inflating: pothole 2 (197).jpg
#   inflating: pothole 2 (198).jpg
#   inflating: pothole 2 (199).jpg
#   inflating: pothole 2 (200).jpg
#   inflating: pothole 2 (201).jpg
#   inflating: pothole 2 (202).jpg
#   inflating: pothole 2 (203).jpg
#   inflating: pothole 2 (204).jpg
#   inflating: pothole 2 (205).jpg
#   inflating: pothole 2 (206).jpg
#   inflating: pothole 2 (207).jpg
#   inflating: pothole 2 (208).jpg
#   inflating: pothole 2 (209).jpg
#   inflating: pothole 2 (210).jpg
#   inflating: pothole 2 (211).jpg
#   inflating: pothole 2 (212).jpg
#   inflating: pothole 2 (213).jpg
#   inflating: pothole 2 (214).jpg
#   inflating: pothole 2 (215).jpg
#   inflating: pothole 2 (216).jpg
#   inflating: pothole 2 (217).jpg
#   inflating: pothole 2 (218).jpg
#   inflating: pothole 2 (219).jpg
#   inflating: pothole 2 (220).jpg
#   inflating: pothole 2 (221).jpg
#   inflating: pothole 2 (222).jpg
#   inflating: pothole 2 (223).jpg
#   inflating: pothole 2 (224).jpg
#   inflating: pothole 2 (225).jpg
#   inflating: pothole 2 (226).jpg
#   inflating: pothole 2 (227).jpg
#   inflating: pothole 2 (228).jpg
#   inflating: pothole 2 (229).jpg
#   inflating: pothole 2 (230).jpg
#   inflating: pothole 2 (231).jpg
#   inflating: pothole 2 (232).jpg
#   inflating: pothole 2 (233).jpg
#   inflating: pothole 2 (234).jpg
#   inflating: pothole 2 (235).jpg
#   inflating: pothole 2 (236).jpg
#   inflating: pothole 2 (237).jpg
#   inflating: pothole 2 (238).jpg
#   inflating: pothole 2 (239).jpg
#   inflating: pothole 2 (240).jpg
#   inflating: pothole 2 (241).jpg
#   inflating: pothole 2 (242).jpg
#   inflating: pothole 2 (243).jpg
#   inflating: pothole 2 (244).jpg
#   inflating: pothole 2 (245).jpg
#   inflating: pothole 2 (246).jpg
#   inflating: pothole 2 (247).jpg
#   inflating: pothole 2 (248).jpg
#   inflating: pothole 2 (249).jpg
#   inflating: pothole 2 (250).jpg
#   inflating: pothole 2 (251).jpg
#   inflating: pothole 2 (252).jpg
#   inflating: pothole 2 (253).jpg
#   inflating: pothole 2 (254).jpg
#   inflating: pothole 2 (255).jpg
#   inflating: pothole 2 (256).jpg
#   inflating: pothole 2 (257).jpg
#   inflating: pothole 2 (258).jpg
#   inflating: pothole 2 (259).jpg
#   inflating: pothole 2 (260).jpg
#   inflating: pothole 2 (261).jpg
#   inflating: pothole 2 (262).jpg
#   inflating: pothole 2 (263).jpg
#   inflating: pothole 2 (264).jpg
#   inflating: pothole 2 (265).jpg
#   inflating: pothole 2 (266).jpg
#   inflating: pothole 2 (267).jpg
#   inflating: pothole 2 (268).jpg
#   inflating: pothole 2 (269).jpg
#   inflating: pothole 2 (270).jpg
#   inflating: pothole 2 (271).jpg
#   inflating: pothole 2 (272).jpg
#   inflating: pothole 2 (273).jpg
#   inflating: pothole 2 (274).jpg
#   inflating: pothole 2 (275).jpg
#   inflating: pothole 2 (276).jpg
#   inflating: pothole 2 (277).jpg
#   inflating: pothole 2 (278).jpg
#   inflating: pothole 2 (279).jpg
#   inflating: pothole 2 (280).jpg
#   inflating: pothole 2 (281).jpg
#   inflating: pothole 2 (282).jpg
#   inflating: pothole 2 (283).jpg
#   inflating: pothole 2 (284).jpg
#   inflating: pothole 2 (285).jpg
#   inflating: pothole 2 (286).jpg
#   inflating: pothole 2 (287).jpg
#   inflating: pothole 2 (288).jpg
#   inflating: pothole 2 (289).jpg
#   inflating: pothole 2 (290).jpg
#   inflating: pothole 2 (291).jpg
#   inflating: pothole 2 (292).jpg
#   inflating: pothole 2 (293).jpg
#   inflating: pothole 2 (294).jpg
#   inflating: pothole 2 (295).jpg
#   inflating: pothole 2 (296).jpg
#   inflating: pothole 2 (297).jpg
#   inflating: pothole 2 (298).jpg
#   inflating: pothole 2 (299).jpg
#   inflating: pothole 2 (300).jpg
#   inflating: pothole 2 (301).jpg
#   inflating: pothole 2 (302).jpg
#   inflating: pothole 2 (303).jpg
#   inflating: pothole 2 (304).jpg
#   inflating: pothole 2 (305).jpg
#   inflating: pothole 2 (306).jpg
#   inflating: pothole 2 (307).jpg
#   inflating: pothole 2 (308).jpg
#   inflating: pothole 2 (309).jpg
#   inflating: pothole 2 (310).jpg

# %%
# %cd ..
# Out:
# /content/detection/workspace/data/images

# %%
# %cd ./train
# Out:
# /content/detection/workspace/data/images/train

# %%
# !unzip /content/detector/train.zip
# Out:
# Archive:  /content/detector/train.zip
#   inflating: pothole (1).jpg
#   inflating: pothole (2).jpg
#   inflating: pothole (3).jpg
#   inflating: pothole (5).jpg
#   inflating: pothole (6).jpg
#   inflating: pothole (7).jpg
#   inflating: pothole (8).jpg
#   inflating: pothole (9).jpg
#   inflating: pothole (10).jpg
#   inflating: pothole (11).jpg
#   inflating: pothole (12).jpg
#   inflating: pothole (13).jpg
#   inflating: pothole (14).jpg
#   inflating: pothole (15).jpg
#   inflating: pothole (16).jpg
#   inflating: pothole (17).jpg
#   inflating: pothole (18).jpg
#   inflating: pothole (19).jpg
#   inflating: pothole (20).jpg
#   inflating: pothole (21).jpg
#   inflating: pothole (22).jpg
#   inflating: pothole (23).jpg
#   inflating: pothole (25).jpg
#   inflating: pothole (26).jpg
#   inflating: pothole (27).jpg
#   inflating: pothole (28).jpg
#   inflating: pothole (30).jpg
#   inflating: pothole (31).jpg
#   inflating: pothole (32).jpg
#   inflating: pothole (33).jpg
#   inflating: pothole (34).jpg
#   inflating: pothole (35).jpg
#   inflating: pothole (38).jpg
#   inflating: pothole (39).jpg
#   inflating: pothole (40).jpg
#   inflating: pothole (43).jpg
#   inflating: pothole (46).jpg
#   inflating: pothole (47).jpg
#   inflating: pothole (48).jpg
#   inflating: pothole (49).jpg
#   inflating: pothole (50).jpg
#   inflating: pothole (51).jpg
#   inflating: pothole (52).jpg
#   inflating: pothole (53).jpg
#   inflating: pothole (54).jpg
#   inflating: pothole (55).jpg
#   inflating: pothole (56).jpg
#   inflating: pothole (57).jpg
#   inflating: pothole (58).jpg
#   inflating: pothole (59).jpg
#   inflating: pothole (60).jpg
#   inflating: pothole (61).jpg
#   inflating: pothole (62).jpg
#   inflating: pothole (63).jpg
#   inflating: pothole (64).jpg
#   inflating: pothole (66).jpg
#   inflating: pothole (70).jpg
#   inflating: pothole (71).jpg
#   inflating: pothole (72).jpg
#   inflating: pothole (73).jpg
#   inflating: pothole (74).jpg
#   inflating: pothole (75).jpg
#   inflating: pothole (76).jpg
#   inflating: pothole (77).jpg
#   inflating: pothole (78).jpg
#   inflating: pothole (79).jpg
#   inflating: pothole (80).jpg
#   inflating: pothole (81).jpg
#   inflating: pothole (82).jpg
#   inflating: pothole (83).jpg
#   inflating: pothole (84).jpg
#   inflating: pothole (85).jpg
#   inflating: pothole (86).jpg
#   inflating: pothole (87).jpg
#   inflating: pothole (88).jpg
#   inflating: pothole (89).jpg
#   inflating: pothole (90).jpg
#   inflating: pothole (91).jpg
#   inflating: pothole (92).jpg
#   inflating: pothole (93).jpg
#   inflating: pothole (94).jpg
#   inflating: pothole (95).jpg
#   inflating: pothole (96).jpg
#   inflating: pothole (97).jpg
#   inflating: pothole (98).jpg
#   inflating: pothole (99).jpg
#   inflating: pothole (100).jpg
#   inflating: pothole (102).jpg
#   inflating: pothole (103).jpg
#   inflating: pothole (104).jpg
#   inflating: pothole (105).jpg
#   inflating: pothole (106).jpg
#   inflating: pothole (107).jpg
#   inflating: pothole (108).jpg
#   inflating: pothole (109).jpg
#   inflating: pothole (110).jpg
#   inflating: pothole (111).jpg
#   inflating: pothole (112).jpg
#   inflating: pothole (113).jpg
#   inflating: pothole (114).jpg
#   inflating: pothole (115).jpg
#   inflating: pothole (116).jpg
#   inflating: pothole (117).jpg
#   inflating: pothole (118).jpg
#   inflating: pothole (119).jpg
#   inflating: pothole (120).jpg
#   inflating: pothole (121).jpg
#   inflating: pothole (122).jpg
#   inflating: pothole (123).jpg
#   inflating: pothole (124).jpg
#   inflating: pothole (125).jpg
#   inflating: pothole (126).jpg
#   inflating: pothole (127).jpg
#   inflating: pothole (128).jpg
#   inflating: pothole (129).jpg
#   inflating: pothole (130).jpg
#   inflating: pothole (131).jpg
#   inflating: pothole (132).jpg
#   inflating: pothole (133).jpg
#   inflating: pothole (134).jpg
#   inflating: pothole (135).jpg
#   inflating: pothole (136).jpg
#   inflating: pothole (138).jpg
#   inflating: pothole (139).jpg
#   inflating: pothole (140).jpg
#   inflating: pothole (141).jpg
#   inflating: pothole (142).jpg
#   inflating: pothole (143).jpg
#   inflating: pothole (144).jpg
#   inflating: pothole (145).jpg
#   inflating: pothole (147).jpg
#   inflating: pothole (148).jpg
#   inflating: pothole (149).jpg
#   inflating: pothole (150).jpg
#   inflating: pothole (151).jpg
#   inflating: pothole (152).jpg
#   inflating: pothole (153).jpg
#   inflating: pothole (154).jpg
#   inflating: pothole (155).jpg
#   inflating: pothole (156).jpg
#   inflating: pothole (157).jpg
#   inflating: pothole (158).jpg
#   inflating: pothole (159).jpg
#   inflating: pothole (160).jpg
#   inflating: pothole (161).jpg
#   inflating: pothole (162).jpg
#   inflating: pothole (163).jpg
#   inflating: pothole (164).jpg
#   inflating: pothole (165).jpg
#   inflating: pothole (166).jpg
#   inflating: pothole (167).jpg
#   inflating: pothole (168).jpg
#   inflating: pothole (169).jpg
#   inflating: pothole (170).jpg
#   inflating: pothole (171).jpg
#   inflating: pothole (172).jpg
#   inflating: pothole (173).jpg
#   inflating: pothole (174).jpg
#   inflating: pothole (175).jpg
#   inflating: pothole (176).jpg
#   inflating: pothole (177).jpg
#   inflating: pothole (178).jpg
#   inflating: pothole (179).jpg
#   inflating: pothole (180).jpg
#   inflating: pothole (181).jpg
#   inflating: pothole (182).jpg
#   inflating: pothole (183).jpg
#   inflating: pothole (184).jpg
#   inflating: pothole (185).jpg
#   inflating: pothole (186).jpg
#   inflating: pothole (187).jpg
#   inflating: pothole (188).jpg
#   inflating: pothole (189).jpg
#   inflating: pothole (190).jpg
#   inflating: pothole (191).jpg
#   inflating: pothole (192).jpg
#   inflating: pothole (193).jpg
#   inflating: pothole (194).jpg
#   inflating: pothole (195).jpg
#   inflating: pothole (196).jpg
#   inflating: pothole (197).jpg
#   inflating: pothole (198).jpg
#   inflating: pothole (199).jpg
#   inflating: pothole (200).jpg
#   inflating: pothole (201).jpg
#   inflating: pothole (202).jpg
#   inflating: pothole (203).jpg
#   inflating: pothole (204).jpg
#   inflating: pothole (205).jpg
#   inflating: pothole (206).jpg
#   inflating: pothole (207).jpg
#   inflating: pothole (208).jpg
#   inflating: pothole (209).jpg
#   inflating: pothole (210).jpg
#   inflating: pothole (211).jpg
#   inflating: pothole (212).jpg
#   inflating: pothole (213).jpg
#   inflating: pothole (214).jpg
#   inflating: pothole (215).jpg
#   inflating: pothole (216).jpg
#   inflating: pothole (217).jpg
#   inflating: pothole (219).jpg
#   inflating: pothole (220).jpg
#   inflating: pothole (221).jpg
#   inflating: pothole (222).jpg
#   inflating: pothole (223).jpg
#   inflating: pothole (224).jpg
#   inflating: pothole (225).jpg
#   inflating: pothole (226).jpg
#   inflating: pothole (227).jpg
#   inflating: pothole (228).jpg
#   inflating: pothole (229).jpg
#   inflating: pothole (230).jpg
#   inflating: pothole (231).jpg
#   inflating: pothole (232).jpg
#   inflating: pothole (233).jpg
#   inflating: pothole (234).jpg
#   inflating: pothole (235).jpg
#   inflating: pothole (236).jpg
#   inflating: pothole (237).jpg
#   inflating: pothole (238).jpg
#   inflating: pothole (239).jpg
#   inflating: pothole (240).jpg
#   inflating: pothole (241).jpg
#   inflating: pothole (242).jpg
#   inflating: pothole (243).jpg
#   inflating: pothole (244).jpg
#   inflating: pothole (245).jpg
#   inflating: pothole (246).jpg
#   inflating: pothole (247).jpg
#   inflating: pothole (248).jpg
#   inflating: pothole (249).jpg
#   inflating: pothole (250).jpg
#   inflating: pothole (251).jpg
#   inflating: pothole (253).jpg
#   inflating: pothole (254).jpg
#   inflating: pothole (255).jpg
#   inflating: pothole (256).jpg
#   inflating: pothole (257).jpg
#   inflating: pothole (258).jpg
#   inflating: pothole (259).jpg
#   inflating: pothole (261).jpg
#   inflating: pothole (264).jpg
#   inflating: pothole (265).jpg
#   inflating: pothole (266).jpg
#   inflating: pothole (267).jpg
#   inflating: pothole (268).jpg
#   inflating: pothole (269).jpg
#   inflating: pothole (270).jpg
#   inflating: pothole (271).jpg
#   inflating: pothole (272).jpg
#   inflating: pothole (274).jpg
#   inflating: pothole (275).jpg
#   inflating: pothole (276).jpg
#   inflating: pothole (277).jpg
#   inflating: pothole (278).jpg
#   inflating: pothole (279).jpg
#   inflating: pothole (280).jpg
#   inflating: pothole (281).jpg
#   inflating: pothole (283).jpg
#   inflating: pothole (284).jpg
#   inflating: pothole (285).jpg
#   inflating: pothole (286).jpg
#   inflating: pothole (287).jpg
#   inflating: pothole (288).jpg
#   inflating: pothole (289).jpg
#   inflating: pothole (290).jpg
#   inflating: pothole (291).jpg
#   inflating: pothole (292).jpg
#   inflating: pothole (293).jpg
#   inflating: pothole (294).jpg
#   inflating: pothole (295).jpg
#   inflating: pothole (296).jpg
#   inflating: pothole (297).jpg
#   inflating: pothole (299).jpg
#   inflating: pothole (300).jpg
#   inflating: pothole (301).jpg
#   inflating: pothole (302).jpg
#   inflating: pothole (303).jpg
#   inflating: pothole (304).jpg
#   inflating: pothole (305).jpg
#   inflating: pothole (306).jpg
#   inflating: pothole (307).jpg
#   inflating: pothole (308).jpg
#   inflating: pothole (309).jpg
#   inflating: pothole (310).jpg
#   inflating: pothole (312).jpg
#   inflating: pothole (313).jpg
#   inflating: pothole (314).jpg
#   inflating: pothole (315).jpg
#   inflating: pothole (319).jpg
#   inflating: pothole (320).jpg
#   inflating: pothole (321).jpg
#   inflating: pothole (322).jpg
#   inflating: pothole (323).jpg
#   inflating: pothole (324).jpg
#   inflating: pothole (325).jpg
#   inflating: pothole (326).jpg
#   inflating: pothole (327).jpg
#   inflating: pothole (329).jpg
#   inflating: pothole (331).jpg
#   inflating: pothole (332).jpg
#   inflating: pothole (334).jpg
#   inflating: pothole (335).jpg
#   inflating: pothole (337).jpg
#   inflating: pothole (338).jpg
#   inflating: pothole (339).jpg
#   inflating: pothole (340).jpg
#   inflating: pothole (342).jpg
#   inflating: pothole (343).jpg
#   inflating: pothole (344).jpg
#   inflating: pothole (347).jpg
#   inflating: pothole (348).jpg
#   inflating: pothole (349).jpg
#   inflating: pothole (350).jpg
#   inflating: pothole (351).jpg
#   inflating: pothole (352).jpg
#   inflating: pothole (353).jpg
#   inflating: pothole (354).jpg
#   inflating: pothole (355).jpg
#   inflating: pothole (356).jpg
#   inflating: pothole (360).jpg
#   inflating: pothole (361).jpg
#   inflating: pothole (363).jpg
#   inflating: pothole (364).jpg
#   inflating: pothole (365).jpg
#   inflating: pothole (366).jpg
#   inflating: pothole (368).jpg
#   inflating: pothole (371).jpg
#   inflating: pothole (372).jpg
#   inflating: pothole (373).jpg
#   inflating: pothole (374).jpg
#   inflating: pothole (375).jpg
#   inflating: pothole (376).jpg
#   inflating: pothole (377).jpg
#   inflating: pothole (378).jpg
#   inflating: pothole (379).jpg
#   inflating: pothole (380).jpg
#   inflating: pothole (381).jpg
#   inflating: pothole (382).jpg
#   inflating: pothole (383).jpg
#   inflating: pothole (384).jpg
#   inflating: pothole (385).jpg
#   inflating: pothole (386).jpg
#   inflating: pothole (387).jpg
#   inflating: pothole (388).jpg
#   inflating: pothole (389).jpg
#   inflating: pothole (390).jpg
#   inflating: pothole (391).jpg
#   inflating: pothole (392).jpg
#   inflating: pothole (393).jpg
#   inflating: pothole (394).jpg
#   inflating: pothole (395).jpg
#   inflating: pothole (396).jpg
#   inflating: pothole (397).jpg
#   inflating: pothole (398).jpg
#   inflating: pothole (399).jpg
#   inflating: pothole (400).jpg
#   inflating: pothole (401).jpg
#   inflating: pothole (402).jpg
#   inflating: pothole (403).jpg
#   inflating: pothole (404).jpg
#   inflating: pothole (405).jpg
#   inflating: pothole (407).jpg
#   inflating: pothole (409).jpg
#   inflating: pothole (411).jpg
#   inflating: pothole (413).jpg
#   inflating: pothole (414).jpg
#   inflating: pothole (415).jpg
#   inflating: pothole (416).jpg
#   inflating: pothole (417).jpg
#   inflating: pothole (418).jpg
#   inflating: pothole (419).jpg
#   inflating: pothole (420).jpg
#   inflating: pothole (422).jpg
#   inflating: pothole (423).jpg
#   inflating: pothole (424).jpg
#   inflating: pothole (425).jpg
#   inflating: pothole (426).jpg
#   inflating: pothole (427).jpg
#   inflating: pothole (428).jpg
#   inflating: pothole (429).jpg
#   inflating: pothole (430).jpg
#   inflating: pothole (431).jpg
#   inflating: pothole (432).jpg
#   inflating: pothole (433).jpg
#   inflating: pothole (434).jpg
#   inflating: pothole (435).jpg
#   inflating: pothole (436).jpg
#   inflating: pothole (437).jpg
#   inflating: pothole (438).jpg
#   inflating: pothole (439).jpg
#   inflating: pothole (440).jpg
#   inflating: pothole (441).jpg
#   inflating: pothole (442).jpg
#   inflating: pothole (443).jpg
#   inflating: pothole (444).jpg
#   inflating: pothole (445).jpg
#   inflating: pothole (446).jpg
#   inflating: pothole (447).jpg
#   inflating: pothole (448).jpg
#   inflating: pothole (449).jpg
#   inflating: pothole (450).jpg
#   inflating: pothole (451).jpg
#   inflating: pothole (452).jpg
#   inflating: pothole (453).jpg
#   inflating: pothole (454).jpg
#   inflating: pothole (455).jpg
#   inflating: pothole (456).jpg
#   inflating: pothole (457).jpg
#   inflating: pothole (458).jpg
#   inflating: pothole (459).jpg
#   inflating: pothole (460).jpg
#   inflating: pothole (461).jpg
#   inflating: pothole (462).jpg
#   inflating: pothole (463).jpg
#   inflating: pothole (464).jpg
#   inflating: pothole (465).jpg
#   inflating: pothole (466).jpg
#   inflating: pothole (467).jpg
#   inflating: pothole (468).jpg
#   inflating: pothole (469).jpg
#   inflating: pothole (470).jpg
#   inflating: pothole (471).jpg
#   inflating: pothole (472).jpg
#   inflating: pothole (473).jpg
#   inflating: pothole (474).jpg
#   inflating: pothole (475).jpg
#   inflating: pothole (476).jpg
#   inflating: pothole (477).jpg
#   inflating: pothole (478).jpg
#   inflating: pothole (479).jpg
#   inflating: pothole (480).jpg
#   inflating: pothole (481).jpg
#   inflating: pothole (482).jpg
#   inflating: pothole (483).jpg
#   inflating: pothole (484).jpg
#   inflating: pothole (485).jpg
#   inflating: pothole (486).jpg
#   inflating: pothole (487).jpg
#   inflating: pothole (488).jpg
#   inflating: pothole (489).jpg
#   inflating: pothole (490).jpg
#   inflating: pothole (491).jpg
#   inflating: pothole (492).jpg
#   inflating: pothole (493).jpg
#   inflating: pothole (496).jpg
#   inflating: pothole (497).jpg
#   inflating: pothole (498).jpg
#   inflating: pothole (499).jpg
#   inflating: pothole (500).jpg
#   inflating: pothole (501).jpg
#   inflating: pothole (502).jpg
#   inflating: pothole (507).jpg
#   inflating: pothole (509).jpg
#   inflating: pothole (510).jpg
#   inflating: pothole (512).jpg
#   inflating: pothole (513).jpg
#   inflating: pothole (514).jpg
#   inflating: pothole (516).jpg
#   inflating: pothole (517).jpg
#   inflating: pothole (518).jpg
#   inflating: pothole (519).jpg
#   inflating: pothole (520).jpg
#   inflating: pothole (522).jpg
#   inflating: pothole (523).jpg
#   inflating: pothole (524).jpg
#   inflating: pothole (526).jpg
#   inflating: pothole (527).jpg
#   inflating: pothole (528).jpg
#   inflating: pothole (529).jpg
#   inflating: pothole (530).jpg
#   inflating: pothole (531).jpg
#   inflating: pothole (532).jpg
#   inflating: pothole (533).jpg
#   inflating: pothole (534).jpg
#   inflating: pothole (535).jpg
#   inflating: pothole (536).jpg
#   inflating: pothole (537).jpg
#   inflating: pothole (538).jpg
#   inflating: pothole (539).jpg
#   inflating: pothole (542).jpg
#   inflating: pothole (543).jpg
#   inflating: pothole (544).jpg
#   inflating: pothole (545).jpg
#   inflating: pothole (546).jpg
#   inflating: pothole (547).jpg
#   inflating: pothole (548).jpg
#   inflating: pothole (549).jpg
#   inflating: pothole (550).jpg
#   inflating: pothole (553).jpg
#   inflating: pothole (555).jpg
#   inflating: pothole (556).jpg
#   inflating: pothole (559).jpg
#   inflating: pothole (561).jpg
#   inflating: pothole (563).jpg
#   inflating: pothole (568).jpg
#   inflating: pothole (570).jpg
#   inflating: pothole (572).jpg
#   inflating: pothole (573).jpg
#   inflating: pothole (574).jpg
#   inflating: pothole (576).jpg
#   inflating: pothole (577).jpg
#   inflating: pothole (578).jpg
#   inflating: pothole (579).jpg
#   inflating: pothole (580).jpg
#   inflating: pothole (581).jpg
#   inflating: pothole (582).jpg
#   inflating: pothole (583).jpg
#   inflating: pothole (584).jpg
#   inflating: pothole (585).jpg
#   inflating: pothole (586).jpg
#   inflating: pothole (587).jpg
#   inflating: pothole (588).jpg
#   inflating: pothole (589).jpg
#   inflating: pothole (590).jpg
#   inflating: pothole (591).jpg
#   inflating: pothole (592).jpg
#   inflating: pothole (593).jpg
#   inflating: pothole (595).jpg
#   inflating: pothole (596).jpg
#   inflating: pothole (597).jpg
#   inflating: pothole (599).jpg
#   inflating: pothole (602).jpg
#   inflating: pothole (603).jpg
#   inflating: pothole (607).jpg
#   inflating: pothole (608).jpg
#   inflating: pothole (609).jpg
#   inflating: pothole (610).jpg
#   inflating: pothole (613).jpg
#   inflating: pothole (614).jpg
#   inflating: pothole (615).jpg
#   inflating: pothole (616).jpg
#   inflating: pothole (617).jpg
#   inflating: pothole (618).jpg
#   inflating: pothole (619).jpg
#   inflating: pothole (620).jpg
#   inflating: pothole (621).jpg
#   inflating: pothole (622).jpg
#   inflating: pothole (623).jpg
#   inflating: pothole (624).jpg
#   inflating: pothole (625).jpg
#   inflating: pothole (626).jpg
#   inflating: pothole (627).jpg
#   inflating: pothole (628).jpg
#   inflating: pothole (629).jpg
#   inflating: pothole (631).jpg
#   inflating: pothole (632).jpg
#   inflating: pothole (633).jpg
#   inflating: pothole (635).jpg
#   inflating: pothole (636).jpg
#   inflating: pothole (637).jpg
#   inflating: pothole (638).jpg
#   inflating: pothole (640).jpg
#   inflating: pothole (642).jpg
#   inflating: pothole (643).jpg
#   inflating: pothole (644).jpg
#   inflating: pothole (645).jpg
#   inflating: pothole (647).jpg
#   inflating: pothole (648).jpg
#   inflating: pothole (650).jpg
#   inflating: pothole (651).jpg
#   inflating: pothole (652).jpg
#   inflating: pothole (653).jpg
#   inflating: pothole (654).jpg
#   inflating: pothole (655).jpg
#   inflating: pothole (656).jpg
#   inflating: pothole (657).jpg
#   inflating: pothole (658).jpg
#   inflating: pothole (659).jpg
#   inflating: pothole (660).jpg
#   inflating: pothole (662).jpg

# %%
# 1. Run the command below to run tensorboard, --logdir should point to the folder that stores the 
#    checkpoints during training, in this case it is the training folder under the data directory.
# %load_ext tensorboard
# %tensorboard --logdir workspace/data/training

# %%
# %cd ..
# Out:
# /content/detection/workspace/data/images

# %%
config_path ='/content/detection/workspace/data/pre-trained-model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'
train_model(config_path)
# Out:
# python3: can't open file 'workspace/data/model_main_tf2.py': [Errno 2] No such file or directory

# %%
# %cd ..
# Out:
# /content/detection/workspace/data

# %%
# You have to give the script two required arguments
# something like below;
#!python model_main_tf2.py --model_dir=workspace/data/training --pipeline_config_path={path}
# !python model_main_tf2.py

# %%
# !python model_main_tf2.py --model_dir=/content/detection/workspace/data/training --pipeline_config_path={'/content/detection/workspace/data/pre-trained-model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'}
# Out:
# 2020-10-22 19:14:42.841294: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-22 19:14:44.738890: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-22 19:14:44.775053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.775622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-22 19:14:44.775661: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-22 19:14:44.777295: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-22 19:14:44.783612: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-22 19:14:44.783962: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-22 19:14:44.785811: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-22 19:14:44.787386: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-22 19:14:44.791489: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-22 19:14:44.791607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.792180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.792675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-22 19:14:44.799314: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-22 19:14:44.799480: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x22e7640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-22 19:14:44.799508: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-22 19:14:44.904611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.905271: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x22e6bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-22 19:14:44.905302: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-10-22 19:14:44.905558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.906060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-22 19:14:44.906119: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-22 19:14:44.906166: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-22 19:14:44.906193: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-22 19:14:44.906214: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-22 19:14:44.906235: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-22 19:14:44.906257: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-22 19:14:44.906279: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-22 19:14:44.906350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.906879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:44.907372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-22 19:14:44.907415: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-22 19:14:45.495706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-22 19:14:45.495780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-22 19:14:45.495798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-22 19:14:45.496162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:45.497054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-22 19:14:45.497613: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-22 19:14:45.497674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13962 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1022 19:14:45.501859 140343656703872 mirrored_strategy.py:341] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I1022 19:14:45.507352 140343656703872 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1022 19:14:45.507520 140343656703872 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Reading unweighted datasets: ['/content/detection/workspace/data/annotations/train.record']
# I1022 19:14:45.567011 140343656703872 dataset_builder.py:148] Reading unweighted datasets: ['/content/detection/workspace/data/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/detection/workspace/data/annotations/train.record']
# I1022 19:14:45.567740 140343656703872 dataset_builder.py:77] Reading record datasets for input file: ['/content/detection/workspace/data/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1022 19:14:45.567869 140343656703872 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1022 19:14:45.567944 140343656703872 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/detection/models/research/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W1022 19:14:45.575955 140343656703872 deprecation.py:323] From /content/detection/models/research/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /content/detection/models/research/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1022 19:14:45.621006 140343656703872 deprecation.py:323] From /content/detection/models/research/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1022 19:14:51.724092 140343656703872 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1022 19:14:54.439395 140343656703872 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /content/detection/models/research/object_detection/inputs.py:262: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1022 19:14:55.977177 140343656703872 deprecation.py:323] From /content/detection/models/research/object_detection/inputs.py:262: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/detection/models/research/object_detection/model_lib_v2.py:355: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# W1022 19:14:59.251470 140340319164160 deprecation.py:323] From /content/detection/models/research/object_detection/model_lib_v2.py:355: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# 2020-10-22 19:15:16.011713: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-22 19:15:17.477566: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._groundtruth_lists
# W1022 19:15:24.527404 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._groundtruth_lists
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor
# W1022 19:15:24.527819 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._batched_prediction_tensor_names
# W1022 19:15:24.527931 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._batched_prediction_tensor_names
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head
# W1022 19:15:24.528013 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads
# W1022 19:15:24.528087 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._sorted_head_names
# W1022 19:15:24.528188 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._sorted_head_names
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers
# W1022 19:15:24.528255 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads
# W1022 19:15:24.528319 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers
# W1022 19:15:24.528382 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers
# W1022 19:15:24.528446 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background
# W1022 19:15:24.528509 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.0
# W1022 19:15:24.528572 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.1
# W1022 19:15:24.528634 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.2
# W1022 19:15:24.528695 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.3
# W1022 19:15:24.528756 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.4
# W1022 19:15:24.528821 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._additional_projection_layers.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings
# W1022 19:15:24.528887 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background
# W1022 19:15:24.528955 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower
# W1022 19:15:24.529018 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower
# W1022 19:15:24.529080 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0
# W1022 19:15:24.529167 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers
# W1022 19:15:24.529230 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0
# W1022 19:15:24.529297 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1
# W1022 19:15:24.529358 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2
# W1022 19:15:24.529422 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3
# W1022 19:15:24.529484 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4
# W1022 19:15:24.529546 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0
# W1022 19:15:24.529607 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1
# W1022 19:15:24.529671 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2
# W1022 19:15:24.529733 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3
# W1022 19:15:24.529796 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4
# W1022 19:15:24.529862 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.0
# W1022 19:15:24.529925 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.1
# W1022 19:15:24.529987 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.2
# W1022 19:15:24.530049 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.3
# W1022 19:15:24.530119 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.BoxPredictionTower.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.0
# W1022 19:15:24.530184 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.1
# W1022 19:15:24.530255 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.2
# W1022 19:15:24.530313 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.3
# W1022 19:15:24.530377 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._head_scope_conv_layers.ClassPredictionTower.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0.kernel
# W1022 19:15:24.530506 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0.bias
# W1022 19:15:24.530577 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._box_prediction_head._box_encoder_layers.0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0
# W1022 19:15:24.530648 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._prediction_heads.class_predictions_with_background._class_predictor_layers.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.1
# W1022 19:15:24.530709 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.2
# W1022 19:15:24.530767 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.4
# W1022 19:15:24.530845 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.5
# W1022 19:15:24.530916 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.7
# W1022 19:15:24.530978 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.8
# W1022 19:15:24.531040 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.10
# W1022 19:15:24.531114 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.11
# W1022 19:15:24.531178 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.0.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.1
# W1022 19:15:24.531240 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.2
# W1022 19:15:24.531302 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.4
# W1022 19:15:24.531370 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.5
# W1022 19:15:24.531432 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.7
# W1022 19:15:24.531493 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.8
# W1022 19:15:24.531554 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.10
# W1022 19:15:24.531616 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.11
# W1022 19:15:24.531678 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.1.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.1
# W1022 19:15:24.531740 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.2
# W1022 19:15:24.531809 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.4
# W1022 19:15:24.531871 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.5
# W1022 19:15:24.531928 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.7
# W1022 19:15:24.605889 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.8
# W1022 19:15:24.606142 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.10
# W1022 19:15:24.606269 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.11
# W1022 19:15:24.606363 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.2.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.1
# W1022 19:15:24.606451 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.2
# W1022 19:15:24.606533 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.4
# W1022 19:15:24.606613 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.5
# W1022 19:15:24.606694 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.7
# W1022 19:15:24.606774 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.8
# W1022 19:15:24.606851 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.10
# W1022 19:15:24.606956 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.11
# W1022 19:15:24.607039 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.3.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.1
# W1022 19:15:24.607138 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.2
# W1022 19:15:24.607224 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.4
# W1022 19:15:24.607304 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.5
# W1022 19:15:24.607383 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.7
# W1022 19:15:24.607463 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.8
# W1022 19:15:24.607542 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.10
# W1022 19:15:24.607621 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.11
# W1022 19:15:24.607701 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.box_encodings.4.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.1
# W1022 19:15:24.607779 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.2
# W1022 19:15:24.607870 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.4
# W1022 19:15:24.607956 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.5
# W1022 19:15:24.608037 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.7
# W1022 19:15:24.608135 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.8
# W1022 19:15:24.608221 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.10
# W1022 19:15:24.608301 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.11
# W1022 19:15:24.608379 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.0.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.1
# W1022 19:15:24.608458 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.2
# W1022 19:15:24.608537 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.4
# W1022 19:15:24.608615 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.5
# W1022 19:15:24.608694 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.7
# W1022 19:15:24.608774 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.8
# W1022 19:15:24.608854 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.10
# W1022 19:15:24.608948 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.11
# W1022 19:15:24.609028 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.1.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.1
# W1022 19:15:24.609124 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.2
# W1022 19:15:24.609211 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.4
# W1022 19:15:24.609292 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.5
# W1022 19:15:24.609384 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.7
# W1022 19:15:24.609465 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.8
# W1022 19:15:24.609543 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.10
# W1022 19:15:24.609611 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.11
# W1022 19:15:24.609670 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.2.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.1
# W1022 19:15:24.609724 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.2
# W1022 19:15:24.609784 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.4
# W1022 19:15:24.609853 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.5
# W1022 19:15:24.609943 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.5
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.7
# W1022 19:15:24.610021 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.7
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.8
# W1022 19:15:24.610099 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.8
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.10
# W1022 19:15:24.610204 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.11
# W1022 19:15:24.610285 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.3.11
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.1
# W1022 19:15:24.610365 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.2
# W1022 19:15:24.610446 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.4
# W1022 19:15:24.610525 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.4
# WARNING:tensorflow:Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.5
# W1022 19:15:24.610605 140343656703872 util.py:150] Unresolved object in checkpoint: (root).model._box_predictor._base_tower_layers_for_heads.class_predictions_with_background.4.5
# ...
# INFO:tensorflow:Step 8300 per-step time 0.395s loss=2.061
# I1022 20:11:22.957994 140343656703872 model_lib_v2.py:652] Step 8300 per-step time 0.395s loss=2.061
# INFO:tensorflow:Step 8400 per-step time 0.398s loss=2.049
# I1022 20:12:03.115458 140343656703872 model_lib_v2.py:652] Step 8400 per-step time 0.398s loss=2.049
# INFO:tensorflow:Step 8500 per-step time 0.397s loss=2.037
# I1022 20:12:43.343978 140343656703872 model_lib_v2.py:652] Step 8500 per-step time 0.397s loss=2.037
# INFO:tensorflow:Step 8600 per-step time 0.399s loss=1.726
# I1022 20:13:23.486577 140343656703872 model_lib_v2.py:652] Step 8600 per-step time 0.399s loss=1.726
# INFO:tensorflow:Step 8700 per-step time 0.406s loss=1.847
# I1022 20:14:03.574517 140343656703872 model_lib_v2.py:652] Step 8700 per-step time 0.406s loss=1.847
# INFO:tensorflow:Step 8800 per-step time 0.408s loss=1.717
# I1022 20:14:43.787503 140343656703872 model_lib_v2.py:652] Step 8800 per-step time 0.408s loss=1.717
# INFO:tensorflow:Step 8900 per-step time 0.403s loss=2.028
# I1022 20:15:24.113722 140343656703872 model_lib_v2.py:652] Step 8900 per-step time 0.403s loss=2.028
# INFO:tensorflow:Step 9000 per-step time 0.392s loss=1.699
# I1022 20:16:04.327620 140343656703872 model_lib_v2.py:652] Step 9000 per-step time 0.392s loss=1.699
# INFO:tensorflow:Step 9100 per-step time 0.403s loss=1.781
# I1022 20:16:45.753438 140343656703872 model_lib_v2.py:652] Step 9100 per-step time 0.403s loss=1.781
# INFO:tensorflow:Step 9200 per-step time 0.403s loss=1.526
# I1022 20:17:25.993240 140343656703872 model_lib_v2.py:652] Step 9200 per-step time 0.403s loss=1.526
# INFO:tensorflow:Step 9300 per-step time 0.392s loss=1.762
# I1022 20:18:06.341600 140343656703872 model_lib_v2.py:652] Step 9300 per-step time 0.392s loss=1.762
# INFO:tensorflow:Step 9400 per-step time 0.403s loss=1.674
# I1022 20:18:46.494165 140343656703872 model_lib_v2.py:652] Step 9400 per-step time 0.403s loss=1.674
# INFO:tensorflow:Step 9500 per-step time 0.397s loss=1.505
# I1022 20:19:26.696448 140343656703872 model_lib_v2.py:652] Step 9500 per-step time 0.397s loss=1.505
# INFO:tensorflow:Step 9600 per-step time 0.410s loss=1.585
# I1022 20:20:06.818479 140343656703872 model_lib_v2.py:652] Step 9600 per-step time 0.410s loss=1.585
# INFO:tensorflow:Step 9700 per-step time 0.402s loss=1.391
# I1022 20:20:46.975795 140343656703872 model_lib_v2.py:652] Step 9700 per-step time 0.402s loss=1.391
# INFO:tensorflow:Step 9800 per-step time 0.396s loss=1.661
# I1022 20:21:27.176416 140343656703872 model_lib_v2.py:652] Step 9800 per-step time 0.396s loss=1.661
# INFO:tensorflow:Step 9900 per-step time 0.397s loss=1.431
# I1022 20:22:07.378534 140343656703872 model_lib_v2.py:652] Step 9900 per-step time 0.397s loss=1.431
# INFO:tensorflow:Step 10000 per-step time 0.401s loss=1.482
# I1022 20:22:47.732787 140343656703872 model_lib_v2.py:652] Step 10000 per-step time 0.401s loss=1.482
# INFO:tensorflow:Step 10100 per-step time 0.396s loss=1.477
# I1022 20:23:29.498316 140343656703872 model_lib_v2.py:652] Step 10100 per-step time 0.396s loss=1.477
# INFO:tensorflow:Step 10200 per-step time 0.403s loss=1.405
# I1022 20:24:09.857384 140343656703872 model_lib_v2.py:652] Step 10200 per-step time 0.403s loss=1.405
# INFO:tensorflow:Step 10300 per-step time 0.410s loss=1.438
# I1022 20:24:50.224238 140343656703872 model_lib_v2.py:652] Step 10300 per-step time 0.410s loss=1.438
# INFO:tensorflow:Step 10400 per-step time 0.407s loss=1.297
# I1022 20:25:30.823964 140343656703872 model_lib_v2.py:652] Step 10400 per-step time 0.407s loss=1.297
# INFO:tensorflow:Step 10500 per-step time 0.397s loss=1.393
# I1022 20:26:11.429756 140343656703872 model_lib_v2.py:652] Step 10500 per-step time 0.397s loss=1.393
# INFO:tensorflow:Step 10600 per-step time 0.399s loss=1.336
# I1022 20:26:51.790076 140343656703872 model_lib_v2.py:652] Step 10600 per-step time 0.399s loss=1.336
# INFO:tensorflow:Step 10700 per-step time 0.397s loss=1.303
# I1022 20:27:32.213757 140343656703872 model_lib_v2.py:652] Step 10700 per-step time 0.397s loss=1.303
# INFO:tensorflow:Step 10800 per-step time 0.405s loss=1.394
# I1022 20:28:12.584703 140343656703872 model_lib_v2.py:652] Step 10800 per-step time 0.405s loss=1.394
# INFO:tensorflow:Step 10900 per-step time 0.395s loss=1.261
# I1022 20:28:52.855417 140343656703872 model_lib_v2.py:652] Step 10900 per-step time 0.395s loss=1.261
# INFO:tensorflow:Step 11000 per-step time 0.395s loss=1.388
# I1022 20:29:33.136703 140343656703872 model_lib_v2.py:652] Step 11000 per-step time 0.395s loss=1.388
# INFO:tensorflow:Step 11100 per-step time 0.401s loss=1.379
# I1022 20:30:14.659523 140343656703872 model_lib_v2.py:652] Step 11100 per-step time 0.401s loss=1.379
# INFO:tensorflow:Step 11200 per-step time 0.403s loss=1.386
# I1022 20:30:54.917233 140343656703872 model_lib_v2.py:652] Step 11200 per-step time 0.403s loss=1.386
# INFO:tensorflow:Step 11300 per-step time 0.406s loss=1.344
# I1022 20:31:35.147046 140343656703872 model_lib_v2.py:652] Step 11300 per-step time 0.406s loss=1.344
# INFO:tensorflow:Step 11400 per-step time 0.398s loss=1.293
# I1022 20:32:15.458555 140343656703872 model_lib_v2.py:652] Step 11400 per-step time 0.398s loss=1.293
# INFO:tensorflow:Step 11500 per-step time 0.395s loss=1.311
# I1022 20:32:55.701114 140343656703872 model_lib_v2.py:652] Step 11500 per-step time 0.395s loss=1.311
# INFO:tensorflow:Step 11600 per-step time 0.398s loss=1.343
# I1022 20:33:35.957468 140343656703872 model_lib_v2.py:652] Step 11600 per-step time 0.398s loss=1.343
# INFO:tensorflow:Step 11700 per-step time 0.406s loss=1.238
# I1022 20:34:16.182684 140343656703872 model_lib_v2.py:652] Step 11700 per-step time 0.406s loss=1.238
# INFO:tensorflow:Step 11800 per-step time 0.395s loss=1.259
# I1022 20:34:56.473144 140343656703872 model_lib_v2.py:652] Step 11800 per-step time 0.395s loss=1.259
# INFO:tensorflow:Step 11900 per-step time 0.396s loss=1.365
# I1022 20:35:36.731972 140343656703872 model_lib_v2.py:652] Step 11900 per-step time 0.396s loss=1.365
# INFO:tensorflow:Step 12000 per-step time 0.402s loss=1.246
# I1022 20:36:17.065989 140343656703872 model_lib_v2.py:652] Step 12000 per-step time 0.402s loss=1.246
# INFO:tensorflow:Step 12100 per-step time 0.395s loss=1.322
# I1022 20:36:58.212822 140343656703872 model_lib_v2.py:652] Step 12100 per-step time 0.395s loss=1.322
# INFO:tensorflow:Step 12200 per-step time 0.397s loss=1.178
# I1022 20:37:38.538497 140343656703872 model_lib_v2.py:652] Step 12200 per-step time 0.397s loss=1.178
# INFO:tensorflow:Step 12300 per-step time 0.409s loss=1.191
# I1022 20:38:18.700787 140343656703872 model_lib_v2.py:652] Step 12300 per-step time 0.409s loss=1.191
# INFO:tensorflow:Step 12400 per-step time 0.409s loss=1.352
# I1022 20:38:59.095130 140343656703872 model_lib_v2.py:652] Step 12400 per-step time 0.409s loss=1.352
# INFO:tensorflow:Step 12500 per-step time 0.402s loss=1.335
# I1022 20:39:39.486649 140343656703872 model_lib_v2.py:652] Step 12500 per-step time 0.402s loss=1.335
# INFO:tensorflow:Step 12600 per-step time 0.403s loss=1.270
# I1022 20:40:19.818370 140343656703872 model_lib_v2.py:652] Step 12600 per-step time 0.403s loss=1.270
# INFO:tensorflow:Step 12700 per-step time 0.406s loss=1.314
# I1022 20:41:00.116443 140343656703872 model_lib_v2.py:652] Step 12700 per-step time 0.406s loss=1.314
# INFO:tensorflow:Step 12800 per-step time 0.409s loss=1.482
# I1022 20:41:40.294724 140343656703872 model_lib_v2.py:652] Step 12800 per-step time 0.409s loss=1.482
# INFO:tensorflow:Step 12900 per-step time 0.397s loss=1.387
# I1022 20:42:20.596804 140343656703872 model_lib_v2.py:652] Step 12900 per-step time 0.397s loss=1.387
# INFO:tensorflow:Step 13000 per-step time 0.403s loss=1.094
# I1022 20:43:00.840210 140343656703872 model_lib_v2.py:652] Step 13000 per-step time 0.403s loss=1.094
# INFO:tensorflow:Step 13100 per-step time 0.407s loss=1.256
# I1022 20:43:42.093313 140343656703872 model_lib_v2.py:652] Step 13100 per-step time 0.407s loss=1.256
# INFO:tensorflow:Step 13200 per-step time 0.409s loss=1.238
# I1022 20:44:22.538672 140343656703872 model_lib_v2.py:652] Step 13200 per-step time 0.409s loss=1.238
# INFO:tensorflow:Step 13300 per-step time 0.401s loss=1.320
# I1022 20:45:02.911176 140343656703872 model_lib_v2.py:652] Step 13300 per-step time 0.401s loss=1.320
# INFO:tensorflow:Step 13400 per-step time 0.420s loss=1.165
# I1022 20:45:43.072667 140343656703872 model_lib_v2.py:652] Step 13400 per-step time 0.420s loss=1.165
# INFO:tensorflow:Step 13500 per-step time 0.419s loss=1.284
# I1022 20:46:23.421770 140343656703872 model_lib_v2.py:652] Step 13500 per-step time 0.419s loss=1.284
# INFO:tensorflow:Step 13600 per-step time 0.397s loss=0.949
# I1022 20:47:03.743059 140343656703872 model_lib_v2.py:652] Step 13600 per-step time 0.397s loss=0.949
# INFO:tensorflow:Step 13700 per-step time 0.409s loss=1.089
# I1022 20:47:44.188886 140343656703872 model_lib_v2.py:652] Step 13700 per-step time 0.409s loss=1.089
# INFO:tensorflow:Step 13800 per-step time 0.399s loss=1.220
# I1022 20:48:24.537790 140343656703872 model_lib_v2.py:652] Step 13800 per-step time 0.399s loss=1.220
# INFO:tensorflow:Step 13900 per-step time 0.408s loss=1.205
# I1022 20:49:04.806950 140343656703872 model_lib_v2.py:652] Step 13900 per-step time 0.408s loss=1.205
# INFO:tensorflow:Step 14000 per-step time 0.403s loss=0.894
# I1022 20:49:45.195695 140343656703872 model_lib_v2.py:652] Step 14000 per-step time 0.403s loss=0.894
# INFO:tensorflow:Step 14100 per-step time 0.411s loss=0.951
# I1022 20:50:26.416449 140343656703872 model_lib_v2.py:652] Step 14100 per-step time 0.411s loss=0.951
# INFO:tensorflow:Step 14200 per-step time 0.407s loss=1.302
# I1022 20:51:06.788463 140343656703872 model_lib_v2.py:652] Step 14200 per-step time 0.407s loss=1.302
# INFO:tensorflow:Step 14300 per-step time 0.386s loss=1.122
# I1022 20:51:47.213156 140343656703872 model_lib_v2.py:652] Step 14300 per-step time 0.386s loss=1.122
# INFO:tensorflow:Step 14400 per-step time 0.391s loss=0.956
# I1022 20:52:27.411483 140343656703872 model_lib_v2.py:652] Step 14400 per-step time 0.391s loss=0.956
# INFO:tensorflow:Step 14500 per-step time 0.401s loss=1.035
# I1022 20:53:07.747071 140343656703872 model_lib_v2.py:652] Step 14500 per-step time 0.401s loss=1.035
# INFO:tensorflow:Step 14600 per-step time 0.401s loss=1.491
# I1022 20:53:48.348539 140343656703872 model_lib_v2.py:652] Step 14600 per-step time 0.401s loss=1.491
# INFO:tensorflow:Step 14700 per-step time 0.405s loss=0.967
# I1022 20:54:29.099541 140343656703872 model_lib_v2.py:652] Step 14700 per-step time 0.405s loss=0.967
# INFO:tensorflow:Step 14800 per-step time 0.409s loss=1.218
# I1022 20:55:09.624529 140343656703872 model_lib_v2.py:652] Step 14800 per-step time 0.409s loss=1.218
# INFO:tensorflow:Step 14900 per-step time 0.407s loss=1.113
# I1022 20:55:50.066867 140343656703872 model_lib_v2.py:652] Step 14900 per-step time 0.407s loss=1.113
# INFO:tensorflow:Step 15000 per-step time 0.405s loss=1.013
# I1022 20:56:30.568835 140343656703872 model_lib_v2.py:652] Step 15000 per-step time 0.405s loss=1.013
# INFO:tensorflow:Step 15100 per-step time 0.411s loss=0.871
# I1022 20:57:11.834033 140343656703872 model_lib_v2.py:652] Step 15100 per-step time 0.411s loss=0.871
# INFO:tensorflow:Step 15200 per-step time 0.400s loss=0.914
# I1022 20:57:52.174362 140343656703872 model_lib_v2.py:652] Step 15200 per-step time 0.400s loss=0.914
# INFO:tensorflow:Step 15300 per-step time 0.399s loss=0.896
# I1022 20:58:32.655798 140343656703872 model_lib_v2.py:652] Step 15300 per-step time 0.399s loss=0.896
# INFO:tensorflow:Step 15400 per-step time 0.410s loss=0.925
# I1022 20:59:13.021673 140343656703872 model_lib_v2.py:652] Step 15400 per-step time 0.410s loss=0.925
# INFO:tensorflow:Step 15500 per-step time 0.399s loss=0.936
# I1022 20:59:53.328766 140343656703872 model_lib_v2.py:652] Step 15500 per-step time 0.399s loss=0.936
# INFO:tensorflow:Step 15600 per-step time 0.402s loss=0.942
# I1022 21:00:33.722839 140343656703872 model_lib_v2.py:652] Step 15600 per-step time 0.402s loss=0.942
# INFO:tensorflow:Step 15700 per-step time 0.398s loss=1.172
# I1022 21:01:14.185080 140343656703872 model_lib_v2.py:652] Step 15700 per-step time 0.398s loss=1.172
# INFO:tensorflow:Step 15800 per-step time 0.409s loss=0.953
# I1022 21:01:54.551907 140343656703872 model_lib_v2.py:652] Step 15800 per-step time 0.409s loss=0.953
# INFO:tensorflow:Step 15900 per-step time 0.402s loss=0.994
# I1022 21:02:35.149740 140343656703872 model_lib_v2.py:652] Step 15900 per-step time 0.402s loss=0.994
# INFO:tensorflow:Step 16000 per-step time 0.420s loss=1.150
# I1022 21:03:15.499536 140343656703872 model_lib_v2.py:652] Step 16000 per-step time 0.420s loss=1.150
# INFO:tensorflow:Step 16100 per-step time 0.392s loss=0.853
# I1022 21:03:56.810050 140343656703872 model_lib_v2.py:652] Step 16100 per-step time 0.392s loss=0.853
# INFO:tensorflow:Step 16200 per-step time 0.405s loss=0.981
# I1022 21:04:37.199701 140343656703872 model_lib_v2.py:652] Step 16200 per-step time 0.405s loss=0.981
# INFO:tensorflow:Step 16300 per-step time 0.403s loss=0.929
# I1022 21:05:17.666846 140343656703872 model_lib_v2.py:652] Step 16300 per-step time 0.403s loss=0.929
# INFO:tensorflow:Step 16400 per-step time 0.402s loss=1.001
# I1022 21:05:58.031039 140343656703872 model_lib_v2.py:652] Step 16400 per-step time 0.402s loss=1.001
# INFO:tensorflow:Step 16500 per-step time 0.413s loss=0.812
# I1022 21:06:38.671406 140343656703872 model_lib_v2.py:652] Step 16500 per-step time 0.413s loss=0.812
# INFO:tensorflow:Step 16600 per-step time 0.409s loss=0.940
# I1022 21:07:19.694366 140343656703872 model_lib_v2.py:652] Step 16600 per-step time 0.409s loss=0.940
# INFO:tensorflow:Step 16700 per-step time 0.412s loss=0.775
# I1022 21:08:00.519867 140343656703872 model_lib_v2.py:652] Step 16700 per-step time 0.412s loss=0.775
# INFO:tensorflow:Step 16800 per-step time 0.415s loss=0.802
# I1022 21:08:41.618242 140343656703872 model_lib_v2.py:652] Step 16800 per-step time 0.415s loss=0.802
# INFO:tensorflow:Step 16900 per-step time 0.409s loss=0.944
# I1022 21:09:22.523986 140343656703872 model_lib_v2.py:652] Step 16900 per-step time 0.409s loss=0.944
# INFO:tensorflow:Step 17000 per-step time 0.415s loss=0.888
# I1022 21:10:03.343088 140343656703872 model_lib_v2.py:652] Step 17000 per-step time 0.415s loss=0.888
# INFO:tensorflow:Step 17100 per-step time 0.398s loss=0.908
# I1022 21:10:45.176694 140343656703872 model_lib_v2.py:652] Step 17100 per-step time 0.398s loss=0.908
# INFO:tensorflow:Step 17200 per-step time 0.408s loss=0.981
# I1022 21:11:25.836783 140343656703872 model_lib_v2.py:652] Step 17200 per-step time 0.408s loss=0.981
# INFO:tensorflow:Step 17300 per-step time 0.409s loss=0.850
# I1022 21:12:06.753161 140343656703872 model_lib_v2.py:652] Step 17300 per-step time 0.409s loss=0.850
# INFO:tensorflow:Step 17400 per-step time 0.415s loss=0.904
# I1022 21:12:47.588837 140343656703872 model_lib_v2.py:652] Step 17400 per-step time 0.415s loss=0.904
# INFO:tensorflow:Step 17500 per-step time 0.423s loss=0.914
# I1022 21:13:28.204787 140343656703872 model_lib_v2.py:652] Step 17500 per-step time 0.423s loss=0.914
# INFO:tensorflow:Step 17600 per-step time 0.409s loss=0.836
# I1022 21:14:08.830040 140343656703872 model_lib_v2.py:652] Step 17600 per-step time 0.409s loss=0.836
# INFO:tensorflow:Step 17700 per-step time 0.405s loss=0.810
# I1022 21:14:49.360744 140343656703872 model_lib_v2.py:652] Step 17700 per-step time 0.405s loss=0.810
# INFO:tensorflow:Step 17800 per-step time 0.400s loss=0.984
# I1022 21:15:29.767240 140343656703872 model_lib_v2.py:652] Step 17800 per-step time 0.400s loss=0.984
# INFO:tensorflow:Step 17900 per-step time 0.405s loss=0.816
# I1022 21:16:10.123529 140343656703872 model_lib_v2.py:652] Step 17900 per-step time 0.405s loss=0.816
# INFO:tensorflow:Step 18000 per-step time 0.407s loss=0.741
# I1022 21:16:50.470154 140343656703872 model_lib_v2.py:652] Step 18000 per-step time 0.407s loss=0.741
# INFO:tensorflow:Step 18100 per-step time 0.406s loss=0.946
# I1022 21:17:31.887348 140343656703872 model_lib_v2.py:652] Step 18100 per-step time 0.406s loss=0.946

# %%
path = r'/content/detection/workspace/data/pre-trained-model/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'
checkpoint_dir = r'/content/detection/workspace/data/training'
export_dir = r
